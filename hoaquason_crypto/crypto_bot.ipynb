# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#remark: "mount Drive" before running the code
#put this python notebook file under the src directory

#to refresh the code properly: should pick "Restart and run all", 
#otherwise: "Runtime --> disconnect and delete runtime"

import warnings
warnings.filterwarnings('ignore')

import os
import sys
import json
import requests

#hyper-parameters
project_path = "drive/MyDrive/investment/tung/tung/"
sys.path.insert(0, project_path)
import constants

BINANE_URL = 'https://api.binance.com/api/v1/'
exchange_url = BINANE_URL + 'exchangeInfo'

# !pip install torpy
from torpy.http.requests import TorRequests

with TorRequests() as tor_requests:
  with tor_requests.get_session() as sess:
    print(sess.get("http://httpbin.org/ip").json())


    data = json.loads(requests.get(exchange_url).text)
    print (data)

# import crypto_bot
# crypto_bot.run_bot(0)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# ERROR:torpy.cell_socket:timed out
# ERROR:root:[ignored]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/torpy/cell_socket.py", line 63, in connect
#     self._socket.connect((self._router.ip, self._router.or_port))
#   File "/usr/lib/python3.8/ssl.py", line 1342, in connect
#     self._real_connect(addr, False)
#   File "/usr/lib/python3.8/ssl.py", line 1329, in _real_connect
#     super().connect(addr)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/torpy/utils.py", line 79, in newfn
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/torpy/consesus.py", line 235, in renew
#     raw_string = self.download_consensus(prev_hash)
# ...
